# %%
import numpy as np
import pandas as pd

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data'
wine = pd.read_csv(url)

wine.head()
# Out:
#    1  14.23  1.71  2.43  15.6  127  ...   .28  2.29  5.64  1.04  3.92  1065
# 0  1  13.20  1.78  2.14  11.2  100  ...  0.26  1.28  4.38  1.05  3.40  1050
# 1  1  13.16  2.36  2.67  18.6  101  ...  0.30  2.81  5.68  1.03  3.17  1185
# 2  1  14.37  1.95  2.50  16.8  113  ...  0.24  2.18  7.80  0.86  3.45  1480
# 3  1  13.24  2.59  2.87  21.0  118  ...  0.39  1.82  4.32  1.04  2.93   735
# 4  1  14.20  1.76  2.45  15.2  112  ...  0.34  1.97  6.75  1.05  2.85  1450
#
# [5 rows x 14 columns]

# %%
wine = wine.drop(wine.columns[[0,3,6,8,11,12,13]], axis=1)
wine
# Out:
#      14.23  1.71  15.6  127  3.06  2.29   5.64
# 0    13.20  1.78  11.2  100  2.76  1.28   4.38
# 1    13.16  2.36  18.6  101  3.24  2.81   5.68
# 2    14.37  1.95  16.8  113  3.49  2.18   7.80
# 3    13.24  2.59  21.0  118  2.69  1.82   4.32
# 4    14.20  1.76  15.2  112  3.39  1.97   6.75
# ..     ...   ...   ...  ...   ...   ...    ...
# 172  13.71  5.65  20.5   95  0.61  1.06   7.70
# 173  13.40  3.91  23.0  102  0.75  1.41   7.30
# 174  13.27  4.28  20.0  120  0.69  1.35  10.20
# 175  13.17  2.59  20.0  120  0.68  1.46   9.30
# 176  14.13  4.10  24.5   96  0.76  1.35   9.20
#
# [177 rows x 7 columns]

# %%
wine.columns = ['alcohol', 'malic_acid', 'alcalinity_of_ash', 'magnesium', 'flavanoids', 'proanthocyanins', 'hue']
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  ...  flavanoids  proanthocyanins   hue
# 0    13.20        1.78               11.2  ...        2.76             1.28  4.38
# 1    13.16        2.36               18.6  ...        3.24             2.81  5.68
# 2    14.37        1.95               16.8  ...        3.49             2.18  7.80
# 3    13.24        2.59               21.0  ...        2.69             1.82  4.32
# 4    14.20        1.76               15.2  ...        3.39             1.97  6.75
#
# [5 rows x 7 columns]

# %%
wine.iloc[0:3, 0] = np.nan
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  ...  flavanoids  proanthocyanins   hue
# 0      NaN        1.78               11.2  ...        2.76             1.28  4.38
# 1      NaN        2.36               18.6  ...        3.24             2.81  5.68
# 2      NaN        1.95               16.8  ...        3.49             2.18  7.80
# 3    13.24        2.59               21.0  ...        2.69             1.82  4.32
# 4    14.20        1.76               15.2  ...        3.39             1.97  6.75
#
# [5 rows x 7 columns]

# %%
wine.iloc[2:4, 3] = np.nan
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  ...  flavanoids  proanthocyanins   hue
# 0      NaN        1.78               11.2  ...        2.76             1.28  4.38
# 1      NaN        2.36               18.6  ...        3.24             2.81  5.68
# 2      NaN        1.95               16.8  ...        3.49             2.18  7.80
# 3    13.24        2.59               21.0  ...        2.69             1.82  4.32
# 4    14.20        1.76               15.2  ...        3.39             1.97  6.75
#
# [5 rows x 7 columns]

# %%
wine.alcohol.fillna(10, inplace = True)
wine.magnesium.fillna(100, inplace = True)
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  ...  flavanoids  proanthocyanins   hue
# 0    10.00        1.78               11.2  ...        2.76             1.28  4.38
# 1    10.00        2.36               18.6  ...        3.24             2.81  5.68
# 2    10.00        1.95               16.8  ...        3.49             2.18  7.80
# 3    13.24        2.59               21.0  ...        2.69             1.82  4.32
# 4    14.20        1.76               15.2  ...        3.39             1.97  6.75
#
# [5 rows x 7 columns]

# %%
wine.isnull().sum()
# Out:
# alcohol              0
# malic_acid           0
# alcalinity_of_ash    0
# magnesium            0
# flavanoids           0
# proanthocyanins      0
# hue                  0
# dtype: int64

# %%
random_nums = np.random.randint(0,10, size = 10)
random_nums
# Out:
# array([3, 0, 5, 7, 6, 8, 9, 7, 0, 9])

# %%
wine.alcohol[random_nums] = np.nan
wine.head(10)
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  ...  flavanoids  proanthocyanins   hue
# 0      NaN        1.78               11.2  ...        2.76             1.28  4.38
# 1     10.0        2.36               18.6  ...        3.24             2.81  5.68
# 2     10.0        1.95               16.8  ...        3.49             2.18  7.80
# 3      NaN        2.59               21.0  ...        2.69             1.82  4.32
# 4     14.2        1.76               15.2  ...        3.39             1.97  6.75
# 5      NaN        1.87               14.6  ...        2.52             1.98  5.25
# 6      NaN        2.15               17.6  ...        2.51             1.25  5.05
# 7      NaN        1.64               14.0  ...        2.98             1.98  5.20
# 8      NaN        1.35               16.0  ...        3.15             1.85  7.22
# 9      NaN        2.16               18.0  ...        3.32             2.38  5.75
#
# [10 rows x 7 columns]

# %%
wine.isnull().sum()
# Out:
# alcohol              7
# malic_acid           0
# alcalinity_of_ash    0
# magnesium            0
# flavanoids           0
# proanthocyanins      0
# hue                  0
# dtype: int64

# %%
wine = wine.dropna(axis = 0, how = "any")
wine.head()
# Out:
#     alcohol  malic_acid  alcalinity_of_ash  ...  flavanoids  proanthocyanins   hue
# 1     10.00        2.36               18.6  ...        3.24             2.81  5.68
# 2     10.00        1.95               16.8  ...        3.49             2.18  7.80
# 4     14.20        1.76               15.2  ...        3.39             1.97  6.75
# 10    14.12        1.48               16.8  ...        2.43             1.57  5.00
# 11    13.75        1.73               16.0  ...        2.76             1.81  5.60
#
# [5 rows x 7 columns]

# %%
mask = wine.alcohol.notnull()
mask
# Out:
# 1      True
# 2      True
# 4      True
# 10     True
# 11     True
#        ...
# 172    True
# 173    True
# 174    True
# 175    True
# 176    True
# Name: alcohol, Length: 170, dtype: bool

# %%
wine.alcohol[mask]
# Out:
# 1      10.00
# 2      10.00
# 4      14.20
# 10     14.12
# 11     13.75
#        ...
# 172    13.71
# 173    13.40
# 174    13.27
# 175    13.17
# 176    14.13
# Name: alcohol, Length: 170, dtype: float64

# %%
wine = wine.reset_index(drop = True)
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  ...  flavanoids  proanthocyanins   hue
# 0    10.00        2.36               18.6  ...        3.24             2.81  5.68
# 1    10.00        1.95               16.8  ...        3.49             2.18  7.80
# 2    14.20        1.76               15.2  ...        3.39             1.97  6.75
# 3    14.12        1.48               16.8  ...        2.43             1.57  5.00
# 4    13.75        1.73               16.0  ...        2.76             1.81  5.60
#
# [5 rows x 7 columns]
